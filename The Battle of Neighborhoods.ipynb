# %% [markdown]
# # The Battle of Neighborhoods - Relocation Helper

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
# !conda install -c conda-forge folium=0.5.0 --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
pip install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Downloading https://files.pythonhosted.org/packages/e8/b5/7bb03a696f2c9b7af792a8f51b82974e51c268f15e925fc834876a4efa0b/beautifulsoup4-4.9.0-py3-none-any.whl (109kB)
#      |████████████████████████████████| 112kB 3.9MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from BeautifulSoup4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Installing collected packages: soupsieve, BeautifulSoup4
# Successfully installed BeautifulSoup4-4.9.0 soupsieve-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/dd/ba/a0e6866057fc0bbd17192925c1d63a3b85cf522965de9bc02364d08e5b84/lxml-4.5.0-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 6.3MB/s eta 0:00:01     |███████████████████▌            | 3.5MB 6.3MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Neighborhoods in Toronto

# %%
from bs4 import BeautifulSoup
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(url).text
Canada_data = BeautifulSoup(source, 'lxml')

# creat a new Dataframe
column_names = ['PostalCode','Borough','Neighborhood']
toronto = pd.DataFrame(columns = column_names)

# loop through to find postcode, borough, neighborhood 
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text.strip('\n')
            i = i + 1
        elif i == 1:
            borough = td.text.strip('\n')
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
            
    toronto = toronto.append({'PostalCode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# clean dataframe 
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1
                                 
df = toronto.groupby(['PostalCode','Borough'])['Neighborhood'].apply(', '.join).reset_index()

# !wget -q -O 'Toronto_long_lat_data.csv'  http://cocl.us/Geospatial_data
df_lon_lat = pd.read_csv('Toronto_long_lat_data.csv')
df_lon_lat = df_lon_lat.rename(columns={"Postal Code":"PostalCode"})

Toronto_df = pd.merge(df,
                 df_lon_lat[['PostalCode','Latitude', 'Longitude']],
                 on='PostalCode')
Toronto_df.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood  \
# 0        M1B  Scarborough                                   Malvern, Rouge
# 1        M1C  Scarborough           Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 7        M1L  Scarborough                  Golden Mile, Clairlea, Oakridge
# 8        M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476
# 5  43.744734 -79.239476
# 6  43.727929 -79.262029
# 7  43.711112 -79.284577
# 8  43.716316 -79.239476
# 9  43.692657 -79.264848

# %% [markdown]
# ### Map of Neighborhoods in Toronto

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="TO_CA_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(Toronto_df['Latitude'], Toronto_df['Longitude'], Toronto_df['Borough'], Toronto_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add Information from Foursquare

# %%
CLIENT_ID = 'ZXPGFJJXJYHSZUZOGHJ5JMCY0Z02JK1VDZIPGU4JRS3LIUCT'
CLIENT_SECRET = 'Z0SC2CCUEWGM0YDFPIGIDXGLWJ44DC1C0AGLSD4LKVYL03R0'
VERSION = '20180605'

def getNearbyVenues(names, latitudes, longitudes, radius):
    
    venues_list=[]
    remove = []
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        #Log postal codees without nearby addresses 
        if not results:
            remove.append(name)

        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Postal_Code', 
                  'Postal_Latitude', 
                  'Postal_Longitude', 
                  'Venue', 
                  'Venue_Latitude', 
                  'Venue_Longitude', 
                  'Venue_Category']
    
    return(nearby_venues, remove)

#Radius of 750m and a limit of 100 venues
radius = 750
LIMIT = 100

#Get the venues near Toronto postal codes
toronto_venues,remove = getNearbyVenues(names=Toronto_df['PostalCode'],
                                   latitudes=Toronto_df['Latitude'],
                                   longitudes=Toronto_df['Longitude'],
                                   radius = radius
                                  )

#Remove those postal codes with no nearby venues
for item in remove:
    indexNames = Toronto_df[ Toronto_df['PostalCode'] == item ].index
    # Delete these row indexes from dataFrame
    Toronto_df.drop(indexNames , inplace=True)
    
# Display the shape of the dataframe and the first 5 rows
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (3706, 7)
#   Postal_Code  Postal_Latitude  Postal_Longitude                Venue  \
# 0         M1B        43.806686        -79.194353              Wendy’s
# 1         M1B        43.806686        -79.194353              Wendy's
# 2         M1B        43.806686        -79.194353  Staples Morningside
# 3         M1B        43.806686        -79.194353          Tim Hortons
# 4         M1B        43.806686        -79.194353   Images Salon & Spa
#
#    Venue_Latitude  Venue_Longitude                 Venue_Category
# 0       43.807448       -79.199056           Fast Food Restaurant
# 1       43.802008       -79.198080           Fast Food Restaurant
# 2       43.800285       -79.196607  Paper / Office Supplies Store
# 3       43.802000       -79.198169                    Coffee Shop
# 4       43.802283       -79.198565                            Spa

# %% [markdown]
# # Rank Venues from Foursquare

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue_Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot["Postal_Code"] = toronto_venues["Postal_Code"] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# group rows by Postal Code and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby("Postal_Code").mean().reset_index()
print(toronto_grouped.shape)

#Identify top venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5 #Interested in the top 5 venues
indicators = ['st', 'nd', 'rd'] #Numbering indicators (1st, 2nd, 3rd)

# create columns according to number of top venues
columns = ["Postal_Code"]
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
postal_venues_sorted = pd.DataFrame(columns=columns)
postal_venues_sorted["Postal_Code"] = toronto_grouped["Postal_Code"]

for ind in np.arange(toronto_grouped.shape[0]):
    postal_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
    
kclusters = 5 # set number of clusters
toronto_grouped_clustering = toronto_grouped.drop("Postal_Code", 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering) # run k-means clustering

toronto_merged = Toronto_df
toronto_merged['Cluster Labels'] = kmeans.labels_  # add clustering labels

# merge toronto_grouped with toronto_data to add latitude/longitude for each postal code
toronto_merged = toronto_merged.join(postal_venues_sorted.set_index('Postal_Code'), on='PostalCode')
toronto_merged.head(5)
# Out:
# (102, 323)
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353               3  Fast Food Restaurant           Coffee Shop
# 1 -79.160497               1        Breakfast Spot                   Bar
# 2 -79.188711               1  Fast Food Restaurant           Pizza Place
# 3 -79.216917               2           Coffee Shop                  Park
# 4 -79.239476               3           Coffee Shop     Indian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue       5th Most Common Venue
# 0           Bus Station    African Restaurant  Construction & Landscaping
# 1    Italian Restaurant          Burger Joint                 Yoga Studio
# 2            Restaurant            Sports Bar         Fried Chicken Joint
# 3     Convenience Store      Business Service                 Yoga Studio
# 4           Yoga Studio    Chinese Restaurant                Burger Joint

# %% [markdown]
# # Map Toronto clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11) # create map

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Neighborhoods in New York

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset #get data for NY
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
neighborhoods_data = newyork_data['features']

#transform into pandas df
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude']  # define the dataframe columns
neighborhoods = pd.DataFrame(columns=column_names) # instantiate the dataframe

#loop through to fill the df
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods.head(10)
# Out:
#      Borough    Neighborhood   Latitude  Longitude
# 0      Bronx       Wakefield  40.894705 -73.847201
# 1      Bronx      Co-op City  40.874294 -73.829939
# 2      Bronx     Eastchester  40.887556 -73.827806
# 3      Bronx       Fieldston  40.895437 -73.905643
# 4      Bronx       Riverdale  40.890834 -73.912585
# 5      Bronx     Kingsbridge  40.881687 -73.902818
# 6  Manhattan     Marble Hill  40.876551 -73.910660
# 7      Bronx        Woodlawn  40.898273 -73.867315
# 8      Bronx         Norwood  40.877224 -73.879391
# 9      Bronx  Williamsbridge  40.881039 -73.857446

# %% [markdown]
# ### Map of Neighborhoods in New York

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Segment only the neighborhoods in Manhattan

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
address = 'Manhattan, NY'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
manhattan_venues.head()
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066       Arturo's
# 1  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066      Starbucks
# 4  Marble Hill              40.876551               -73.91066        Dunkin'
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       40.874412       -73.910271    Pizza Place
# 1       40.876844       -73.906204    Yoga Studio
# 2       40.880404       -73.908937          Diner
# 3       40.877531       -73.905582    Coffee Shop
# 4       40.877136       -73.906666     Donut Shop

# %%
#how many venues were returned for each neighborhood
print('There are {} uniques categories.'.format(len(manhattan_venues['Venue Category'].unique())))
manhattan_venues.groupby('Neighborhood').count()
# Out:
# There are 328 uniques categories.
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Battery Park City                       61                      61     61
# Carnegie Hill                           84                      84     84
# Central Harlem                          45                      45     45
# Chelsea                                100                     100    100
# Chinatown                              100                     100    100
# Civic Center                            88                      88     88
# Clinton                                100                     100    100
# East Harlem                             43                      43     43
# East Village                           100                     100    100
# Financial District                     100                     100    100
# Flatiron                                98                      98     98
# Gramercy                                72                      72     72
# Greenwich Village                      100                     100    100
# Hamilton Heights                        61                      61     61
# Hudson Yards                            54                      54     54
# Inwood                                  58                      58     58
# Lenox Hill                             100                     100    100
# Lincoln Square                          92                      92     92
# Little Italy                           100                     100    100
# Lower East Side                         39                      39     39
# Manhattan Valley                        40                      40     40
# Manhattanville                          43                      43     43
# Marble Hill                             26                      26     26
# Midtown                                100                     100    100
# Midtown South                           92                      92     92
# Morningside Heights                     40                      40     40
# Murray Hill                             77                      77     77
# Noho                                   100                     100    100
# Roosevelt Island                        26                      26     26
# Soho                                    68                      68     68
# Stuyvesant Town                         17                      17     17
# Sutton Place                            97                      97     97
# Tribeca                                 69                      69     69
# Tudor City                              73                      73     73
# Turtle Bay                             100                     100    100
# Upper East Side                         83                      83     83
# Upper West Side                         70                      70     70
# Washington Heights                      88                      88     88
# West Village                           100                     100    100
# Yorkville                              100                     100    100
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Battery Park City                61               61              61
# Carnegie Hill                    84               84              84
# Central Harlem                   45               45              45
# Chelsea                         100              100             100
# Chinatown                       100              100             100
# Civic Center                     88               88              88
# Clinton                         100              100             100
# East Harlem                      43               43              43
# East Village                    100              100             100
# Financial District              100              100             100
# Flatiron                         98               98              98
# Gramercy                         72               72              72
# Greenwich Village               100              100             100
# Hamilton Heights                 61               61              61
# Hudson Yards                     54               54              54
# Inwood                           58               58              58
# Lenox Hill                      100              100             100
# Lincoln Square                   92               92              92
# Little Italy                    100              100             100
# Lower East Side                  39               39              39
# Manhattan Valley                 40               40              40
# Manhattanville                   43               43              43
# Marble Hill                      26               26              26
# Midtown                         100              100             100
# Midtown South                    92               92              92
# Morningside Heights              40               40              40
# Murray Hill                      77               77              77
# Noho                            100              100             100
# Roosevelt Island                 26               26              26
# Soho                             68               68              68
# Stuyvesant Town                  17               17              17
# Sutton Place                     97               97              97
# Tribeca                          69               69              69
# Tudor City                       73               73              73
# Turtle Bay                      100              100             100
# Upper East Side                  83               83              83
# Upper West Side                  70               70              70
# Washington Heights               88               88              88
# West Village                    100              100             100
# Yorkville                       100              100             100

# %% [markdown]
# # Analyze Each Neighborhood

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()

# print each neighborhood along with the top 5 most common venues
num_top_venues = 5
for hood in manhattan_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = manhattan_grouped[manhattan_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Battery Park City----
#            venue  freq
# 0           Park  0.11
# 1          Hotel  0.07
# 2  Memorial Site  0.05
# 3            Gym  0.05
# 4    Coffee Shop  0.05
#
#
# ----Carnegie Hill----
#            venue  freq
# 0    Coffee Shop  0.08
# 1    Pizza Place  0.05
# 2    Yoga Studio  0.04
# 3  Grocery Store  0.04
# 4           Café  0.04
#
#
# ----Central Harlem----
#                  venue  freq
# 0   African Restaurant  0.07
# 1       Cosmetics Shop  0.07
# 2                  Bar  0.04
# 3   Chinese Restaurant  0.04
# 4  American Restaurant  0.04
#
#
# ----Chelsea----
#                  venue  freq
# 0          Art Gallery  0.16
# 1          Coffee Shop  0.07
# 2                 Café  0.04
# 3       Ice Cream Shop  0.03
# 4  American Restaurant  0.03
#
#
# ----Chinatown----
#                 venue  freq
# 0  Chinese Restaurant  0.08
# 1        Cocktail Bar  0.04
# 2              Bakery  0.04
# 3         Coffee Shop  0.03
# 4                 Spa  0.03
#
#
# ----Civic Center----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Park  0.05
# 2  American Restaurant  0.05
# 3                Hotel  0.05
# 4                  Spa  0.05
#
#
# ----Clinton----
#                   venue  freq
# 0               Theater  0.08
# 1           Coffee Shop  0.05
# 2  Gym / Fitness Center  0.05
# 3             Wine Shop  0.04
# 4                 Hotel  0.04
#
#
# ----East Harlem----
#                        venue  freq
# 0         Mexican Restaurant  0.12
# 1                     Bakery  0.09
# 2            Thai Restaurant  0.07
# 3              Deli / Bodega  0.07
# 4  Latin American Restaurant  0.07
#
#
# ----East Village----
#                    venue  freq
# 0            Pizza Place  0.06
# 1            Coffee Shop  0.04
# 2           Cocktail Bar  0.04
# 3       Ramen Restaurant  0.03
# 4  Vietnamese Restaurant  0.03
#
#
# ----Financial District----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                Hotel  0.05
# 2       Sandwich Place  0.04
# 3          Pizza Place  0.04
# 4  American Restaurant  0.04
#
#
# ----Flatiron----
#                   venue  freq
# 0  Gym / Fitness Center  0.09
# 1    Italian Restaurant  0.05
# 2   American Restaurant  0.03
# 3             Wine Shop  0.03
# 4        Cosmetics Shop  0.03
#
#
# ----Gramercy----
#                 venue  freq
# 0          Bagel Shop  0.06
# 1  Italian Restaurant  0.06
# 2         Coffee Shop  0.06
# 3                 Bar  0.04
# 4          Playground  0.04
#
#
# ----Greenwich Village----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1                 Gym  0.04
# 2         Coffee Shop  0.04
# 3         Pizza Place  0.03
# 4              Bakery  0.03
#
#
# ----Hamilton Heights----
#                 venue  freq
# 0         Pizza Place  0.10
# 1         Coffee Shop  0.07
# 2                Café  0.07
# 3       Deli / Bodega  0.05
# 4  Mexican Restaurant  0.05
#
#
# ----Hudson Yards----
#                   venue  freq
# 0                 Hotel  0.07
# 1  Gym / Fitness Center  0.06
# 2    Italian Restaurant  0.06
# 3   American Restaurant  0.06
# 4                   Gym  0.04
#
#
# ----Inwood----
#                 venue  freq
# 0  Mexican Restaurant  0.07
# 1         Pizza Place  0.05
# 2                Café  0.05
# 3              Lounge  0.05
# 4          Restaurant  0.05
#
#
# ----Lenox Hill----
#                 venue  freq
# 0  Italian Restaurant  0.06
# 1         Coffee Shop  0.06
# 2         Pizza Place  0.05
# 3        Cocktail Bar  0.04
# 4                Café  0.04
#
#
# ----Lincoln Square----
#                   venue  freq
# 0    Italian Restaurant  0.05
# 1                  Café  0.05
# 2                 Plaza  0.05
# 3          Concert Hall  0.04
# 4  Gym / Fitness Center  0.04
#
#
# ----Little Italy----
#                       venue  freq
# 0        Chinese Restaurant  0.05
# 1                       Spa  0.05
# 2        Italian Restaurant  0.04
# 3  Mediterranean Restaurant  0.04
# 4                    Bakery  0.04
#
#
# ----Lower East Side----
#                 venue  freq
# 0  Chinese Restaurant  0.08
# 1                Café  0.05
# 2        Cocktail Bar  0.05
# 3         Art Gallery  0.05
# 4         Yoga Studio  0.03
#
#
# ----Manhattan Valley----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1  Mexican Restaurant  0.05
# 2                 Bar  0.05
# 3                 Spa  0.05
# 4         Yoga Studio  0.02
#
#
# ----Manhattanville----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Seafood Restaurant  0.07
# 2       Deli / Bodega  0.05
# 3  Italian Restaurant  0.05
# 4  Mexican Restaurant  0.05
#
#
# ----Marble Hill----
#                 venue  freq
# 0      Sandwich Place  0.12
# 1         Coffee Shop  0.08
# 2                 Gym  0.08
# 3         Yoga Studio  0.04
# 4  Miscellaneous Shop  0.04
#
#
# ----Midtown----
#               venue  freq
# 0       Coffee Shop  0.07
# 1             Hotel  0.05
# 2    Clothing Store  0.05
# 3           Theater  0.04
# 4  Cuban Restaurant  0.03
#
#
# ----Midtown South----
#                  venue  freq
# 0    Korean Restaurant  0.15
# 1                Hotel  0.08
# 2         Burger Joint  0.04
# 3  Japanese Restaurant  0.04
# 4         Dessert Shop  0.03
#
#
# ----Morningside Heights----
#                  venue  freq
# 0                 Park  0.10
# 1            Bookstore  0.08
# 2  American Restaurant  0.08
# 3          Coffee Shop  0.08
# 4         Burger Joint  0.05
#
#
# ----Murray Hill----
#             venue  freq
# 0     Coffee Shop  0.06
# 1           Hotel  0.06
# 2  Sandwich Place  0.05
# 3     Pizza Place  0.04
# 4      Steakhouse  0.04
#
#
# ----Noho----
#                  venue  freq
# 0   Italian Restaurant  0.06
# 1          Coffee Shop  0.05
# 2  Japanese Restaurant  0.04
# 3        Grocery Store  0.04
# 4       Sandwich Place  0.04
#
#
# ----Roosevelt Island----
#                                       venue  freq
# 0  Residential Building (Apartment / Condo)  0.04
# 1                      Gym / Fitness Center  0.04
# 2                          Greek Restaurant  0.04
# 3                            Farmers Market  0.04
# 4                               Coffee Shop  0.04
#
#
# ----Soho----
#                       venue  freq
# 0        Italian Restaurant  0.09
# 1  Mediterranean Restaurant  0.06
# 2            Clothing Store  0.04
# 3               Coffee Shop  0.04
# 4                       Gym  0.04
#
#
# ----Stuyvesant Town----
#            venue  freq
# 0  Boat or Ferry  0.12
# 1           Park  0.12
# 2   Cocktail Bar  0.06
# 3    Pet Service  0.06
# 4       Fountain  0.06
#
#
# ----Sutton Place----
#                   venue  freq
# 0    Italian Restaurant  0.05
# 1                  Park  0.04
# 2           Coffee Shop  0.04
# 3  Gym / Fitness Center  0.04
# 4                   Gym  0.03
#
#
# ----Tribeca----
#                 venue  freq
# 0                Park  0.07
# 1  Italian Restaurant  0.07
# 2                Café  0.04
# 3            Wine Bar  0.04
# 4                 Spa  0.04
#
#
# ----Tudor City----
#                 venue  freq
# 0                Park  0.07
# 1                Café  0.07
# 2  Mexican Restaurant  0.05
# 3         Pizza Place  0.04
# 4       Deli / Bodega  0.04
#
#
# ----Turtle Bay----
#                 venue  freq
# 0         Coffee Shop  0.05
# 1                Café  0.04
# 2  Italian Restaurant  0.04
# 3            Wine Bar  0.04
# 4                Park  0.04
#
#
# ----Upper East Side----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1  Gym / Fitness Center  0.05
# 2                Bakery  0.05
# 3             Juice Bar  0.05
# 4           Yoga Studio  0.04
#
#
# ----Upper West Side----
#                 venue  freq
# 0         Coffee Shop  0.04
# 1              Bakery  0.04
# 2        Dessert Shop  0.04
# 3            Wine Bar  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Washington Heights----
#                        venue  freq
# 0                       Café  0.06
# 1                     Bakery  0.05
# 2         Chinese Restaurant  0.03
# 3          Mobile Phone Shop  0.03
# 4  Latin American Restaurant  0.02
#
#
# ----West Village----
#                  venue  freq
# 0   Italian Restaurant  0.08
# 1             Wine Bar  0.06
# 2          Coffee Shop  0.05
# 3  American Restaurant  0.05
# 4            Jazz Club  0.04
#
#
# ----Yorkville----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Italian Restaurant  0.07
# 2                 Gym  0.06
# 3       Deli / Bodega  0.04
# 4                 Bar  0.04

# %%
# put that into a pandas df
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

# display top venues per neighborhood
num_top_venues = 5
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(5)
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Battery Park City                  Park                 Hotel
# 1      Carnegie Hill           Coffee Shop           Pizza Place
# 2     Central Harlem    African Restaurant        Cosmetics Shop
# 3            Chelsea           Art Gallery           Coffee Shop
# 4          Chinatown    Chinese Restaurant          Cocktail Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 0           Coffee Shop                   Gym         Memorial Site
# 1                  Café   Japanese Restaurant                   Gym
# 2                   Bar   American Restaurant     French Restaurant
# 3                  Café        Ice Cream Shop   American Restaurant
# 4                Bakery          Optical Shop   American Restaurant

# %% [markdown]
# # Cluster Neighborhoods in NY

# %%
kclusters = 5 # set number of clusters
manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)   # run k-means clustering
kmeans.labels_[0:10]     # check cluster labels generated for each row in the dataframe

neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)     # add clustering labels

manhattan_merged = manhattan_data

# merge to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

manhattan_merged.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               0
# 2  Manhattan  Washington Heights  40.851903 -73.936900               2
# 3  Manhattan              Inwood  40.867684 -73.921210               2
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0        Sandwich Place                   Gym           Coffee Shop
# 1    Chinese Restaurant          Cocktail Bar                Bakery
# 2                  Café                Bakery     Mobile Phone Shop
# 3    Mexican Restaurant            Restaurant                  Café
# 4           Pizza Place           Coffee Shop                  Café
#
#   4th Most Common Venue      5th Most Common Venue
# 0                 Diner                 Steakhouse
# 1          Optical Shop        American Restaurant
# 2    Chinese Restaurant  Latin American Restaurant
# 3                Lounge                Pizza Place
# 4         Deli / Bodega         Mexican Restaurant

# %% [markdown]
# # Map NY clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### NYC Cluster 1

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 0, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 6     Central Harlem    African Restaurant        Cosmetics Shop
# 20   Lower East Side    Chinese Restaurant           Art Gallery
# 1          Chinatown    Chinese Restaurant          Cocktail Bar
# 30     Carnegie Hill           Coffee Shop           Pizza Place
# 25  Manhattan Valley           Coffee Shop                   Spa
# 12   Upper West Side    Italian Restaurant          Dessert Shop
# 4   Hamilton Heights           Pizza Place           Coffee Shop
# 19      East Village           Pizza Place           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 6                    Bar   American Restaurant     French Restaurant
# 20                  Café          Cocktail Bar           Yoga Studio
# 1                 Bakery          Optical Shop   American Restaurant
# 30                  Café   Japanese Restaurant                   Gym
# 25                   Bar    Mexican Restaurant   Hawaiian Restaurant
# 12              Wine Bar                Bakery           Coffee Shop
# 4                   Café         Deli / Bodega    Mexican Restaurant
# 19          Cocktail Bar             Juice Bar              Wine Bar

# %% [markdown]
# ### NYC Cluster 2

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#           Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 32        Civic Center           Coffee Shop      French Restaurant
# 29  Financial District           Coffee Shop                  Hotel
# 15             Midtown           Coffee Shop                  Hotel
# 16         Murray Hill           Coffee Shop                  Hotel
# 39        Hudson Yards                 Hotel    American Restaurant
# 11    Roosevelt Island                 Hotel  Outdoors & Recreation
# 13      Lincoln Square    Italian Restaurant                  Plaza
# 33       Midtown South     Korean Restaurant                  Hotel
# 28   Battery Park City                  Park                  Hotel
# 14             Clinton               Theater            Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 32   American Restaurant                  Park                 Hotel
# 29   American Restaurant        Sandwich Place           Pizza Place
# 15        Clothing Store               Theater           Pizza Place
# 16        Sandwich Place  Gym / Fitness Center            Steakhouse
# 39  Gym / Fitness Center    Italian Restaurant                  Café
# 11         Metro Station           Supermarket     Food & Drink Shop
# 13                  Café  Gym / Fitness Center               Theater
# 33          Burger Joint   Japanese Restaurant           Coffee Shop
# 28           Coffee Shop                   Gym         Memorial Site
# 14  Gym / Fitness Center                   Gym             Wine Shop

# %% [markdown]
# ### NYC Cluster 3

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 2, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 2    Washington Heights                  Café                Bakery
# 36           Tudor City                  Café                  Park
# 5        Manhattanville           Coffee Shop    Seafood Restaurant
# 7           East Harlem    Mexican Restaurant                Bakery
# 3                Inwood    Mexican Restaurant            Restaurant
# 26  Morningside Heights                  Park             Bookstore
# 0           Marble Hill        Sandwich Place                   Gym
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue
# 2      Mobile Phone Shop    Chinese Restaurant  Latin American Restaurant
# 36    Mexican Restaurant         Deli / Bodega                Pizza Place
# 5     Italian Restaurant    Mexican Restaurant         Chinese Restaurant
# 7          Deli / Bodega       Thai Restaurant  Latin American Restaurant
# 3                   Café                Lounge                Pizza Place
# 26   American Restaurant           Coffee Shop              Deli / Bodega
# 0            Coffee Shop                 Diner                 Steakhouse

# %% [markdown]
# ### NYC Cluster 4

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 3, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#          Neighborhood 1st Most Common Venue     2nd Most Common Venue  \
# 17            Chelsea           Art Gallery               Coffee Shop
# 22       Little Italy    Chinese Restaurant                       Spa
# 35         Turtle Bay           Coffee Shop        Italian Restaurant
# 38           Flatiron  Gym / Fitness Center        Italian Restaurant
# 27           Gramercy    Italian Restaurant                Bagel Shop
# 8     Upper East Side    Italian Restaurant                    Bakery
# 31               Noho    Italian Restaurant               Coffee Shop
# 9           Yorkville    Italian Restaurant               Coffee Shop
# 18  Greenwich Village    Italian Restaurant               Coffee Shop
# 34       Sutton Place    Italian Restaurant               Coffee Shop
# 10         Lenox Hill    Italian Restaurant               Coffee Shop
# 23               Soho    Italian Restaurant  Mediterranean Restaurant
# 21            Tribeca    Italian Restaurant                      Park
# 24       West Village    Italian Restaurant                  Wine Bar
#
#    3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue
# 17                  Café        Ice Cream Shop       American Restaurant
# 22    Italian Restaurant                Bakery  Mediterranean Restaurant
# 35                  Café              Wine Bar                      Park
# 38   American Restaurant             Wine Shop        Salon / Barbershop
# 27           Coffee Shop            Playground               Pizza Place
# 8   Gym / Fitness Center             Juice Bar                       Spa
# 31         Grocery Store   Japanese Restaurant            Sandwich Place
# 9                    Gym         Deli / Bodega                       Bar
# 18                   Gym           Pizza Place            Ice Cream Shop
# 34  Gym / Fitness Center                  Park                Bagel Shop
# 10           Pizza Place      Sushi Restaurant              Cocktail Bar
# 23           Coffee Shop        Clothing Store                       Gym
# 21              Wine Bar                  Café                       Spa
# 24   American Restaurant           Coffee Shop                 Jazz Club

# %% [markdown]
# ### NYC Cluster 5

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 37  Stuyvesant Town         Boat or Ferry                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 37                   Bar  Gym / Fitness Center        Baseball Field

# %% [markdown]
# ### Toronto cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 96  North York               0                Bakery   Arts & Crafts Store
# 79  North York               0          Home Service                Bakery
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 96           Pizza Place           Yoga Studio   Dumpling Restaurant
# 79           Yoga Studio   Dumpling Restaurant   Distribution Center

# %% [markdown]
# ### Toronto cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#          Borough  Cluster Labels 1st Most Common Venue  \
# 1    Scarborough               1        Breakfast Spot
# 15   Scarborough               1  Fast Food Restaurant
# 2    Scarborough               1  Fast Food Restaurant
# 24    North York               1         Grocery Store
# 101    Etobicoke               1         Grocery Store
# 31    North York               1         Grocery Store
# 98          York               1              Pharmacy
# 99     Etobicoke               1           Pizza Place
# 11   Scarborough               1           Pizza Place
# 94     Etobicoke               1           Pizza Place
# 8    Scarborough               1           Wings Joint
#
#          2nd Most Common Venue      3rd Most Common Venue  \
# 1                          Bar         Italian Restaurant
# 15                 Pizza Place         Chinese Restaurant
# 2                  Pizza Place                 Restaurant
# 24                 Coffee Shop                       Park
# 101                Pizza Place                 Beer Store
# 31               Shopping Mall                Coffee Shop
# 98                 Pizza Place                       Park
# 99              Discount Store  Middle Eastern Restaurant
# 11   Middle Eastern Restaurant               Burger Joint
# 94                     Theater         Mexican Restaurant
# 8               Hardware Store                Pizza Place
#
#      4th Most Common Venue 5th Most Common Venue
# 1             Burger Joint           Yoga Studio
# 15           Grocery Store          Noodle House
# 2               Sports Bar   Fried Chicken Joint
# 24             Pizza Place                  Bank
# 101   Fast Food Restaurant   Fried Chicken Joint
# 31   Vietnamese Restaurant           Pizza Place
# 98     Fried Chicken Joint             Gift Shop
# 99             Coffee Shop           Gas Station
# 11           Grocery Store            Restaurant
# 94             Coffee Shop                 Hotel
# 8             Burger Joint    Chinese Restaurant

# %% [markdown]
# ### Toronto cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 91         Etobicoke               2        Baseball Field
# 25        North York               2              Bus Stop
# 3        Scarborough               2           Coffee Shop
# 23        North York               2                  Park
# 50  Downtown Toronto               2                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 91                  Park     Convenience Store  Gym / Fitness Center
# 25                  Park     Food & Drink Shop                  Road
# 3                   Park     Convenience Store      Business Service
# 23                   Gym         Bowling Alley     Convenience Store
# 50                 Trail           Candy Store            Playground
#
#    5th Most Common Venue
# 91   Dumpling Restaurant
# 25           Yoga Studio
# 3            Yoga Studio
# 23                  Bank
# 50           Yoga Studio

# %% [markdown]
# ### Toronto cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#               Borough  Cluster Labels   1st Most Common Venue  \
# 90          Etobicoke               3                  Bakery
# 83       West Toronto               3                     Bar
# 27         North York               3              Beer Store
# 81               York               3                 Brewery
# 44    Central Toronto               3        Business Service
# 67   Downtown Toronto               3                    Café
# 84       West Toronto               3                    Café
# 43       East Toronto               3                    Café
# 58   Downtown Toronto               3                    Café
# 95          Etobicoke               3                    Café
# 40          East York               3                    Café
# 78       West Toronto               3                    Café
# 82       West Toronto               3                    Café
# 66   Downtown Toronto               3                    Café
# 17         North York               3      Chinese Restaurant
# 71         North York               3          Clothing Store
# 18         North York               3          Clothing Store
# 30         North York               3             Coffee Shop
# 45    Central Toronto               3             Coffee Shop
# 59   Downtown Toronto               3             Coffee Shop
# 55   Downtown Toronto               3             Coffee Shop
# 61   Downtown Toronto               3             Coffee Shop
# 69   Downtown Toronto               3             Coffee Shop
# 85   Downtown Toronto               3             Coffee Shop
# 86        Mississauga               3             Coffee Shop
# 46    Central Toronto               3             Coffee Shop
# 6         Scarborough               3             Coffee Shop
# 38          East York               3             Coffee Shop
# 56   Downtown Toronto               3             Coffee Shop
# 60   Downtown Toronto               3             Coffee Shop
# 70   Downtown Toronto               3             Coffee Shop
# 4         Scarborough               3             Coffee Shop
# 47    Central Toronto               3             Coffee Shop
# 57   Downtown Toronto               3             Coffee Shop
# 54   Downtown Toronto               3             Coffee Shop
# 52   Downtown Toronto               3             Coffee Shop
# 53   Downtown Toronto               3             Coffee Shop
# 28         North York               3             Coffee Shop
# 51   Downtown Toronto               3             Coffee Shop
# 65    Central Toronto               3             Coffee Shop
# 76       West Toronto               3             Coffee Shop
# 49    Central Toronto               3             Coffee Shop
# 9         Scarborough               3         College Stadium
# 89          Etobicoke               3       Convenience Store
# 80               York               3            Dessert Shop
# 87       East Toronto               3    Fast Food Restaurant
# 29         North York               3    Fast Food Restaurant
# 0         Scarborough               3    Fast Food Restaurant
# 14        Scarborough               3    Fast Food Restaurant
# 35          East York               3    Fast Food Restaurant
# 73               York               3                   Field
# 10        Scarborough               3  Furniture / Home Store
# 97         North York               3             Gas Station
# 33         North York               3             Gas Station
# 72         North York               3             Gas Station
# 41       East Toronto               3        Greek Restaurant
# 75   Downtown Toronto               3           Grocery Store
# 92          Etobicoke               3    Gym / Fitness Center
# 64    Central Toronto               3    Gym / Fitness Center
# 68   Downtown Toronto               3         Harbor / Marina
# 5         Scarborough               3          Ice Cream Shop
# 39          East York               3       Indian Restaurant
# 21         North York               3       Indian Restaurant
# 42       East Toronto               3       Indian Restaurant
# 7         Scarborough               3            Intersection
# 62         North York               3      Italian Restaurant
# 19         North York               3     Japanese Restaurant
# 26         North York               3     Japanese Restaurant
# 22         North York               3       Korean Restaurant
# 88          Etobicoke               3      Mexican Restaurant
# 48    Central Toronto               3                    Park
# 74               York               3                    Park
# 93          Etobicoke               3                Pharmacy
# 13        Scarborough               3                Pharmacy
# 32         North York               3                Pharmacy
# 63    Central Toronto               3              Playground
# 12        Scarborough               3               Pool Hall
# 34         North York               3   Portuguese Restaurant
# 37       East Toronto               3                     Pub
# 102         Etobicoke               3     Rental Car Location
# 77       West Toronto               3              Restaurant
# 100         Etobicoke               3          Sandwich Place
# 36          East York               3            Skating Rink
#
#              2nd Most Common Venue          3rd Most Common Venue  \
# 90                            Bank                 Breakfast Spot
# 83                            Café                Thai Restaurant
# 27             Japanese Restaurant               Asian Restaurant
# 81                     Pizza Place         Furniture / Home Store
# 44                        Bus Line                    Coffee Shop
# 67                             Bar  Vegetarian / Vegan Restaurant
# 84                     Coffee Shop                         Bakery
# 43                     Coffee Shop                            Bar
# 58                     Coffee Shop                          Hotel
# 95                     Coffee Shop                   Liquor Store
# 40                     Coffee Shop                    Pizza Place
# 78                     Coffee Shop                     Restaurant
# 82              Italian Restaurant                            Bar
# 66                      Restaurant                    Pizza Place
# 17                   Shopping Mall                    Pizza Place
# 71               Accessories Store                     Restaurant
# 18                     Coffee Shop            Japanese Restaurant
# 30                         Airport                 Sandwich Place
# 45                             Bar                    Pizza Place
# 59                   Boat or Ferry                          Hotel
# 55                            Café                      Gastropub
# 61                            Café                          Hotel
# 69                            Café            Japanese Restaurant
# 85                            Café                 Sandwich Place
# 86              Chinese Restaurant                          Hotel
# 46                  Clothing Store                           Café
# 6                Convenience Store                 Sandwich Place
# 38               Electronics Store            Sporting Goods Shop
# 56                           Hotel                           Café
# 60                           Hotel                           Café
# 70                           Hotel                           Café
# 4                Indian Restaurant                    Yoga Studio
# 47              Italian Restaurant                     Restaurant
# 57             Japanese Restaurant                           Café
# 54             Japanese Restaurant                          Hotel
# 52             Japanese Restaurant               Sushi Restaurant
# 53                            Park                        Theater
# 28                     Pizza Place                           Bank
# 51                     Pizza Place                           Café
# 65                     Pizza Place                 Sandwich Place
# 76           Portuguese Restaurant                            Bar
# 49                Sushi Restaurant             Italian Restaurant
# 9                            Diner                           Café
# 89                     Pizza Place                       Pharmacy
# 80                     Gas Station                      Wine Shop
# 87                             Bar                         Bakery
# 29                             Bar                  Metro Station
# 0                      Coffee Shop                    Bus Station
# 14                     Pizza Place             Chinese Restaurant
# 35                     Pizza Place                 Soccer Stadium
# 73                        Pharmacy                          Trail
# 10               Electronics Store                         Bakery
# 97                  Discount Store                   Home Service
# 33                   Grocery Store           Fast Food Restaurant
# 72                   Grocery Store            Japanese Restaurant
# 41                     Coffee Shop                            Pub
# 75                            Park                           Café
# 92                     Coffee Shop             Italian Restaurant
# 64                     Dry Cleaner               Sushi Restaurant
# 68                Airport Terminal                Airport Service
# 5             Fast Food Restaurant                    Coffee Shop
# 39               Afghan Restaurant                           Bank
# 21                     Coffee Shop                    Pizza Place
# 42            Fast Food Restaurant                 Sandwich Place
# 7                            Diner                         Bakery
# 62                     Coffee Shop                 Sandwich Place
# 19                            Bank                  Grocery Store
# 26   Paper / Office Supplies Store           Caribbean Restaurant
# 22                     Coffee Shop                    Pizza Place
# 88                            Café                     Restaurant
# 48                   Grocery Store                 Sandwich Place
# 74                   Women's Store             Mexican Restaurant
# 93                            Café                  Shopping Mall
# 13                     Pizza Place                    Coffee Shop
# 32           Vietnamese Restaurant                     Food Truck
# 63                          Garden                   Home Service
# 12                 Badminton Court                 Clothing Store
# 34                            Park                           Café
# 37                Asian Restaurant            Japanese Restaurant
# 102                      Drugstore                    Yoga Studio
# 77                             Bar                           Café
# 100                    Coffee Shop                       Bus Line
# 36                            Park             Athletics & Sports
#
#              4th Most Common Venue          5th Most Common Venue
# 90                Sushi Restaurant                            Bar
# 83                  Breakfast Spot                     Restaurant
# 27                             Gym                    Coffee Shop
# 81                     Coffee Shop             Athletics & Sports
# 44                     Swim School              Electronics Store
# 67                     Coffee Shop             Mexican Restaurant
# 84              Italian Restaurant                           Park
# 43                          Bakery                 Sandwich Place
# 58                         Theater                 Clothing Store
# 95                  Cosmetics Shop                    Pizza Place
# 40            Fast Food Restaurant                       Beer Bar
# 78                             Bar                         Bakery
# 82                 Thai Restaurant                           Park
# 66                     Coffee Shop                         Bakery
# 17                          Bakery                    Coffee Shop
# 71          Furniture / Home Store           Fast Food Restaurant
# 18                      Restaurant                           Bank
# 30                            Park                     Food Court
# 45                             Gym                           Café
# 59                            Park                       Aquarium
# 55                      Restaurant             Seafood Restaurant
# 61             American Restaurant                     Restaurant
# 69                           Hotel                     Restaurant
# 85              Italian Restaurant                      Gastropub
# 86             Fried Chicken Joint                  Burrito Place
# 46             Sporting Goods Shop                   Skating Rink
# 6              Rental Car Location                           Bank
# 38          Furniture / Home Store                           Bank
# 56                      Restaurant            Japanese Restaurant
# 60             American Restaurant             Seafood Restaurant
# 70                      Restaurant             Seafood Restaurant
# 4               Chinese Restaurant                   Burger Joint
# 47                     Pizza Place           Fast Food Restaurant
# 57                     Art Gallery                 Clothing Store
# 54                Ramen Restaurant                      Gastropub
# 52                     Men's Store                           Café
# 53                            Café                     Restaurant
# 28                     Supermarket                          Diner
# 51                      Restaurant                           Park
# 65                            Café  Vegetarian / Vegan Restaurant
# 76                             Gym             Italian Restaurant
# 49                      Restaurant                           Café
# 9                  Thai Restaurant          General Entertainment
# 89                    Skating Rink                 Sandwich Place
# 80                  Discount Store                     Restaurant
# 87                            Park             Light Rail Station
# 29                     Pizza Place             Miscellaneous Shop
# 0               African Restaurant     Construction & Landscaping
# 14             Japanese Restaurant                       Pharmacy
# 35                            Bank             Athletics & Sports
# 73                            Park              Korean Restaurant
# 10               Indian Restaurant             Chinese Restaurant
# 97               Convenience Store                     Shoe Store
# 33                  Discount Store                       Pharmacy
# 72                      Restaurant      Latin American Restaurant
# 41                            Café                  Grocery Store
# 75               Indian Restaurant                          Diner
# 92               Convenience Store                           Bank
# 64                        Bus Line                          Trail
# 68                   Boat or Ferry                 Airport Lounge
# 5                      Pizza Place                     Restaurant
# 39                     Coffee Shop                 Sandwich Place
# 21                  Sandwich Place                           Bank
# 42                   Grocery Store                     Restaurant
# 7                             Park                    Bus Station
# 62                      Hobby Shop                           Bank
# 19              Chinese Restaurant                  Shopping Mall
# 26            Gym / Fitness Center                           Café
# 22                Ramen Restaurant                     Restaurant
# 88            Fast Food Restaurant               Sushi Restaurant
# 48                             Gym                Thai Restaurant
# 74             Sporting Goods Shop                         Bakery
# 93                      Playground                   Skating Rink
# 13               Convenience Store           Fast Food Restaurant
# 32                  Baseball Field            Dumpling Restaurant
# 63                  Ice Cream Shop                    Yoga Studio
# 12                  Sandwich Place                 Discount Store
# 34                      Playground                   Hockey Arena
# 37                  Breakfast Spot                 Sandwich Place
# 102                    Dry Cleaner                 Discount Store
# 77   Vegetarian / Vegan Restaurant                   Cocktail Bar
# 100                   Intersection                    Supermarket
# 36                        Pharmacy                          Diner

# %% [markdown]
# ### Toronto cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]].sort_values(by=['1st Most Common Venue', '2nd Most Common Venue', '3rd Most Common Venue'])
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 20  North York               4                  Pool           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 20   Dumpling Restaurant   Distribution Center              Dive Bar
